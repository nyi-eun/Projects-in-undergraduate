# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family='malgun gothic')
plt.rc('axes', unicode_minus=False)
# %matplotlib inline
import seaborn as sns
sns.set_theme(style='whitegrid', font_scale=1.5)
sns.set_palette('Set2', n_colors=10)
plt.rc('font', family='malgun gothic')  
plt.rc('axes', unicode_minus=False)

# %%
df1= pd.read_csv('성북구 시간대별 피해운전자_전처리.csv',encoding='cp949')
df2= pd.read_csv('성북구 시간대별 가해운전자_전처리.csv',encoding='cp949')

# %%
df1
# Out:
#       연도    시간대  사고건수합계
# 0   2019    0~4       8
# 1   2019   8~12       3
# 2   2019  14~18      12
# 3   2019  18~22       7
# 4   2020    0~4       3
# 5   2020   8~12       1
# 6   2020  14~18      11
# 7   2020  18~22       2
# 8   2021    0~4       2
# 9   2021   8~12       3
# 10  2021  14~18      14
# 11  2021  18~22       7

# %%
df2
# Out:
#       연도    시간대  사고건수합계
# 0   2019    0~4       4
# 1   2019   8~12       6
# 2   2019  14~18       6
# 3   2019  18~20       5
# 4   2020    0~4       3
# 5   2020   8~12       5
# 6   2020  14~18      14
# 7   2020  18~22       4
# 8   2021    0~6       2
# 9   2021   8~12       6
# 10  2021  14~18      17
# 11  2021  18~22       6

# %%
year19 = df1[df1['연도']==2019]
year20 = df1[df1['연도']==2020]
year21 = df1[df1['연도']==2021]

# %%
plt.xticks(np.arange(1, 13,1), labels=['Jan','Feb','Mar','April', 'May', 'June','July','Aug','Sep','Oct','Nov','Dec'],rotation=45,size=13)

# %%
fig, ax = plt.subplots(3, 1, sharey=True,figsize=(10,10))


ax[0].plot(year19['시간대'],year19['사고건수합계'], color='b')
ax[1].plot(year20['시간대'],year20['사고건수합계'], color='g')
ax[2].plot(year21['시간대'],year21['사고건수합계'], color='r')


ax[2].set_xlabel('시간대별')

ax[0].set_ylabel('사고건수합계')
ax[1].set_ylabel('사고건수합계')
ax[2].set_ylabel('사고건수합계');

#ax[0].plt.legend('')
ax[0].legend(['2019'],loc = 'upper left')
ax[1].legend(['2020'],loc = 'upper left')
ax[2].legend(['2021'],loc = 'upper left')


ax[0].set_title("성북구 사고 시간대별 피해운전자");

# %% [markdown]
# #### 가해운전자

# %%
year19 = df2[df2['연도']==2019]
year20 = df2[df2['연도']==2020]
year21 = df2[df2['연도']==2021]

# %%
fig, ax = plt.subplots(3, 1, sharey=True,figsize=(10,10))


ax[0].plot(year19['시간대'],year19['사고건수합계'], color='b')
ax[1].plot(year20['시간대'],year20['사고건수합계'], color='g')
ax[2].plot(year21['시간대'],year21['사고건수합계'], color='r')


ax[2].set_xlabel('시간대별')

ax[0].set_ylabel('사고건수합계')
ax[1].set_ylabel('사고건수합계')
ax[2].set_ylabel('사고건수합계');

#ax[0].plt.legend('')
ax[0].legend(['2019'],loc = 'upper left')
ax[1].legend(['2020'],loc = 'upper left')
ax[2].legend(['2021'],loc = 'upper left')


ax[0].set_title("성북구 사고 시간대별 가해운전자");
